# %%
# installed
import os
import shutil
import json
import numpy as np

from collections import OrderedDict
from scipy import special
import copy
import cv2
from tqdm import tqdm
import h5py

# must install
import pydicom
import nibabel as nib
import SimpleITK as sitk

# %%
'''! mkdir -p /root/.pip


# %%writefile /root/.pip/pip.conf
[global]
index-url=http://ftp.daumkakao.com/pypi/simple
trusted-host=ftp.daumkakao.com
'''

# %%
def maybe_mkdir_p(directory: str) -> None:
    os.makedirs(directory, exist_ok=True)

maic_dir = '/mnt/backup/'
base_dir = os.path.join(maic_dir, 'working')
input_dir = '/mnt/dataset/'
temp_dir = '/mnt/temp/'

maybe_mkdir_p(base_dir)
maybe_mkdir_p(temp_dir)

! git clone https://github.com/keemsir/nnUNet.git

respository_dir = os.path.join(maic_dir, 'nnUNet')
os.chdir(respository_dir)

! pip install -e .

os.chdir(base_dir)
# Out:
# fatal: destination path 'nnUNet' already exists and is not an empty directory.
# Looking in indexes: http://ftp.daumkakao.com/pypi/simple
# Obtaining file:///mnt/backup/nnUNet
# Requirement already satisfied: torch>=1.6.0a in /usr/local/lib/python3.8/dist-packages (from nnunet==1.7.0) (1.9.1+cu111)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nnunet==1.7.0) (4.62.3)
# Requirement already satisfied: dicom2nifti in /usr/local/lib/python3.8/dist-packages (from nnunet==1.7.0) (2.3.0)
# Requirement already satisfied: scikit-image>=0.14 in /usr/local/lib/python3.8/dist-packages (from nnunet==1.7.0) (0.18.3)
# Requirement already satisfied: medpy in /usr/local/lib/python3.8/dist-packages (from nnunet==1.7.0) (0.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from nnunet==1.7.0) (1.7.1)
# Requirement already satisfied: batchgenerators>=0.23 in /usr/local/lib/python3.8/dist-packages (from nnunet==1.7.0) (0.23)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from nnunet==1.7.0) (1.19.5)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.8/dist-packages (from nnunet==1.7.0) (0.0)
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.8/dist-packages (from nnunet==1.7.0) (2.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from nnunet==1.7.0) (1.3.4)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from nnunet==1.7.0) (2.22.0)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.8/dist-packages (from nnunet==1.7.0) (3.2.1)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.8/dist-packages (from nnunet==1.7.0) (2021.10.12)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.6.0a->nnunet==1.7.0) (3.7.4.3)
# Requirement already satisfied: pydicom>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from dicom2nifti->nnunet==1.7.0) (2.2.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.14->nnunet==1.7.0) (2.9.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.14->nnunet==1.7.0) (1.1.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.14->nnunet==1.7.0) (8.3.2)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.14->nnunet==1.7.0) (3.4.3)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image>=0.14->nnunet==1.7.0) (2.6.3)
# Requirement already satisfied: unittest2 in /usr/local/lib/python3.8/dist-packages (from batchgenerators>=0.23->nnunet==1.7.0) (1.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from batchgenerators>=0.23->nnunet==1.7.0) (1.0)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from batchgenerators>=0.23->nnunet==1.7.0) (0.18.2)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.8/dist-packages (from batchgenerators>=0.23->nnunet==1.7.0) (3.0.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->nnunet==1.7.0) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->nnunet==1.7.0) (2.8.2)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.8/dist-packages (from nibabel->nnunet==1.7.0) (21.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.14->nnunet==1.7.0) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.14->nnunet==1.7.0) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.14->nnunet==1.7.0) (1.3.2)
# Requirement already satisfied: argparse in /usr/local/lib/python3.8/dist-packages (from unittest2->batchgenerators>=0.23->nnunet==1.7.0) (1.4.0)
# Requirement already satisfied: six>=1.4 in /usr/local/lib/python3.8/dist-packages (from unittest2->batchgenerators>=0.23->nnunet==1.7.0) (1.15.0)
# Requirement already satisfied: traceback2 in /usr/local/lib/python3.8/dist-packages (from unittest2->batchgenerators>=0.23->nnunet==1.7.0) (1.4.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->batchgenerators>=0.23->nnunet==1.7.0) (1.1.0)
# Requirement already satisfied: linecache2 in /usr/local/lib/python3.8/dist-packages (from traceback2->unittest2->batchgenerators>=0.23->nnunet==1.7.0) (1.0.0)
# Installing collected packages: nnunet
#   Attempting uninstall: nnunet
#     Found existing installation: nnunet 1.7.0
#     Can't uninstall 'nnunet'. No files were found to uninstall.
#   Running setup.py develop for nnunet
# Successfully installed nnunet
# WARNING: You are using pip version 20.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
task_name = 'Task55_PETCT'
convert_name = 'Task555_PETCT'

main_dir = os.path.join(base_dir, 'nnUNet/nnunet')
mainT_dir = os.path.join(temp_dir, 'nnUNet/nnunet')

rawbase_dir = os.path.join(mainT_dir, 'nnUNet_raw_data_base/')

pp_dir = os.path.join(mainT_dir, 'preprocessed')
tasks_dir = os.path.join(mainT_dir, 'Tasks')
task_dir = os.path.join(tasks_dir, task_name)

model_dir = os.path.join(main_dir, 'nnUNet_trained_models')
Prediction_dir = os.path.join(main_dir, 'nnUNet_Prediction_Results')
result_dir = os.path.join(Prediction_dir, convert_name)

staple_dir = os.path.join(Prediction_dir, 'staple')

# 1. Data preprocessing
maybe_mkdir_p(tasks_dir)
maybe_mkdir_p(temp_dir)

# 2. Directory
maybe_mkdir_p(main_dir)
maybe_mkdir_p(model_dir)
maybe_mkdir_p(pp_dir)

# 3. Directory
maybe_mkdir_p(result_dir)
maybe_mkdir_p(staple_dir)


#Environment Setting
os.environ['nnUNet_raw_data_base'] = rawbase_dir #os.path.join(mainT_dir, 'nnUNet_raw_data_base')
os.environ['nnUNet_preprocessed'] = pp_dir #os.path.join(mainT_dir, 'preprocessed')
os.environ['RESULTS_FOLDER'] = model_dir #os.path.join(main_dir, 'nnUNet_trained_models')


print('Setting Completed!')
# Out:
# Setting Completed!

# %% [markdown]
# # 1-1. Data preprocessing

# %%
def hdf2nifti(hdf_folder: str, save_folder: str):
    # hdf_folder : [train_dir, test_dir] hdf5 file path
    # save_folder : [imagesTr, imagesTs] Save Folder path
    maybe_mkdir_p(os.path.join(save_folder, 'imagesTr'))
    maybe_mkdir_p(os.path.join(save_folder, 'labelsTr'))
    print('Creating "{}" Image & Label ..'.format(os.path.basename(os.path.normpath(save_folder))))
    hdf5_files = os.listdir(hdf_folder)


    for hdf5_file in hdf5_files:


        hdf5_path = os.path.join(hdf_folder, hdf5_file)

        # image
        f_i = h5py.File(hdf5_path, 'r')
        ctarr = np.asarray(f_i['CT'])
        petarr = np.asarray(f_i['PET'])
        labels = np.asarray(f_i['Aorta'])
        f_i.close()

        SLICE_SIZE_X, SLICE_SIZE_Y, SLICE_COUNT = ctarr.shape
        images = np.empty([SLICE_SIZE_X, SLICE_SIZE_Y, SLICE_COUNT, 0], dtype=np.single)

        image_ct = np.expand_dims(ctarr, axis=3)
        images = np.append(images, image_ct, axis=3)
        image_pet = np.expand_dims(petarr, axis=3)
        images = np.append(images, image_pet, axis=3)


        hdf5_file_NAME = hdf5_file

        niim = nib.Nifti1Image(images, affine=np.eye(4))
        nib.save(niim, os.path.join(save_folder, 'imagesTr/{}.nii.gz'.format(hdf5_file[:-8])))

        nila = nib.Nifti1Image(labels, affine=np.eye(4))
        nib.save(nila, os.path.join(save_folder, 'labelsTr/{}.nii.gz'.format(hdf5_file[:-8])))


    print('"{}" Image & Label Completed !!'.format(os.path.basename(os.path.normpath(save_folder))))

hdf2nifti(input_dir, task_dir)
# Out:
# Creating "Task55_PETCT" Image & Label ..
# "Task55_PETCT" Image & Label Completed !!

# %%
def json_mk(save_dir: str):
    # Path
    imagesTr = os.path.join(save_dir, 'imagesTr')
    imagesTs = os.path.join(save_dir, 'imagesTs')
    maybe_mkdir_p(imagesTr)
    maybe_mkdir_p(imagesTs)

    overwrite_json_file = True
    json_file_exist = False

    if os.path.exists(os.path.join(save_dir, 'dataset.json')):
        print('dataset.json already exist!')
        json_file_exist = True

    if json_file_exist == False or overwrite_json_file:

        json_dict = OrderedDict()
        json_dict['name'] = "Kidney"
        json_dict['description'] = "Medical Image AI Challenge 2021"
        json_dict['tensorImageSize'] = "3D"
        json_dict['reference'] = "https://maic.or.kr/competitions/"
        json_dict['licence'] = "SNUH"
        json_dict['release'] = "18/10/2021"

        json_dict['modality'] = {
            "0": "CT",
            "1": "PET"
        }
        json_dict['labels'] = {
            "0": "background",
            "1": "Aorta"
        }

        train_ids = sorted(os.listdir(imagesTr))
        test_ids = sorted(os.listdir(imagesTs))
        json_dict['numTraining'] = len(train_ids)
        json_dict['numTest'] = len(test_ids)

        json_dict['training'] = [{'image': "./imagesTr/%s" % i, "label": "./labelsTr/%s" % i} for i in train_ids]

        json_dict['test'] = ["./imagesTs/%s" % i for i in test_ids] #(i[:i.find("_0000")])

        with open(os.path.join(save_dir, "dataset.json"), 'w') as f:
            json.dump(json_dict, f, indent=4, sort_keys=False)

        if os.path.exists(os.path.join(save_dir, 'dataset.json')):
            if json_file_exist == False:
                print('dataset.json created!')
            else:
                print('dataset.json overwritten!')
json_mk(task_dir)
# Out:
# dataset.json created!

# %% [markdown]
# # 1-2. Data preprocessing

# %%
os.chdir(mainT_dir)
# !nnUNet_convert_decathlon_task -i /mnt/temp/nnUNet/nnunet/Tasks/Task55_PETCT -output_task_id 555 # -i : task_dir
# !nnUNet_plan_and_preprocess -t 555 # --verify_dataset_integrity
os.chdir(base_dir)
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
#
#
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# 23090557_20130
# 23090560_20160
# 23090563_20151
# 23090567_20160
# 23090571_20120
# 23090579_20141
# 23090585_20130
# 23090582_20150
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# 23090558_20120
# 23090572_20130
# 23090561_20120
# 23090580_20131
# 23090568_20121
# 23090586_20120
# 23090564_20130
# 23090583_20160
# before crop: (2, 263, 128, 128) after crop: (2, 263, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# 23090559_20150
# 23090587_20150
# 23090562_20140
# 23090566_20141
# 23090578_20120
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# 23090569_20120
# 23090581_20130
# 23090584_20120
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# 23090588_20131
# 23090591_20140
# 23090594_20160
# 23090597_20130
# 23090600_20121
# 23090604_20140
# 23090608_20120
# 23090611_20150
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# 23090589_20140
# 23090592_20130
# 23090598_20130
# 23090606_20120
# 23090595_20121
# 23090601_20130
# 23090609_20120
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# 23090612_20121
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# 23090607_20120
# 23090599_20140
# 23090590_20121
# 23090593_20120
# 23090596_20150
# 23090603_20141
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# 23090613_20130
# 23090610_20151
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# 23090614_20120
# 23090617_20140
# 23090620_20130
# 23090623_20120
# 23090627_20160
# 23090630_20130
# 23090633_20120
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# 23090636_20121
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# 23090615_20140
# 23090625_20160
# 23090618_20161
# 23090621_20130
# 23090628_20150
# 23090631_20130
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# 23090637_20140
# 23090634_20150
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# 23090616_20140
# 23090629_20120
# 23090626_20160
# 23090622_20150
# 23090619_20121
# 23090632_20130
# 23090638_20131
# 23090635_20140
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# 23090639_20150
# 23090642_20130
# 23090645_20141
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# 23090643_20121
# 23090646_20120
# 23090640_20140
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# 23090641_20160
# 23090644_20131
# before crop: (2, 299, 128, 128) after crop: (2, 299, 128, 128) spacing: [1. 1. 1.]
#
# before crop: (2, 335, 128, 128) after crop: (2, 335, 128, 128) spacing: [1. 1. 1.]
#
#
#
#
#  Task555_PETCT
# number of threads:  (8, 8)
#
# not using nonzero mask for normalization
# Are we using the nonzero mask for normalizaion? OrderedDict([(0, False), (1, False)])
# the median shape of the dataset is  [299. 128. 128.]
# the max shape in the dataset is  [335. 128. 128.]
# the min shape in the dataset is  [263. 128. 128.]
# we don't want feature maps smaller than  4  in the bottleneck
# the transposed median shape of the dataset is  [299. 128. 128.]
# generating configuration for 3d_fullres
# {0: {'batch_size': 2, 'num_pool_per_axis': [5, 4, 4], 'patch_size': array([256,  96,  96]), 'median_patient_size_in_voxels': array([299, 128, 128]), 'current_spacing': array([1., 1., 1.]), 'original_spacing': array([1., 1., 1.]), 'do_dummy_2D_data_aug': False, 'pool_op_kernel_sizes': [[2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 1, 1]], 'conv_kernel_sizes': [[3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]]}}
# transpose forward [0, 1, 2]
# transpose backward [0, 1, 2]
# Initializing to run preprocessing
# npz folder: /mnt/temp/nnUNet/nnunet/nnUNet_raw_data_base/nnUNet_cropped_data/Task555_PETCT
# output_folder: /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 1523
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090557_20130.npz
# 1 1576
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090571_20120.npz
# 1 3800
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090560_20160.npz
# 1 2186
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090579_20141.npz
# 1 2148
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090563_20151.npz
# 1 3219
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090585_20130.npz
# 1 2179
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090582_20150.npz
# 1 2130
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090567_20160.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 263, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 263, 128, 128)}
#
# 1 1998
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090558_20120.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 2276
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090572_20130.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 1764
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090564_20130.npz
# 1 2259
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090561_20120.npz
# 1 1977
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090580_20131.npz
# 1 1980
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090586_20120.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 2223
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090583_20160.npz
# 1 2405
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090568_20121.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 3121
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090559_20150.npz
# no resampling necessary
# no resampling necessary
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after: before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 2047
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090562_20140.npz
# 1 2088
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090566_20141.npz
# 1 2658
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090587_20150.npz
# 1 2753
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090578_20120.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 2928
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090584_20120.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 1188
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090581_20130.npz
# 1 2170
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090569_20120.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 2343
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090588_20131.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 2175
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090591_20140.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 3501
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090594_20160.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 2660
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090597_20130.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 2381
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090600_20121.npz
# 1 1603
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090604_20140.npz
# 1 2943
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090608_20120.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 2569
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090611_20150.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 2579
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090589_20140.npz
# 1 2846
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090592_20130.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 1630
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090598_20130.npz
# 1 2286
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090606_20120.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 1422
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090595_20121.npz
# 1 1385
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090601_20130.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 1909
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090609_20120.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 1721
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090612_20121.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 1803
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090599_20140.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 3163
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090590_20121.npz
# 1 2888
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090593_20120.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 1770
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090607_20120.npz
# 1 2867
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090596_20150.npz
# 1 2984
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090603_20141.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 1447
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090613_20130.npz
# 1 3219
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090610_20151.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 3220
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090614_20120.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 2589
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090617_20140.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 2773
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090623_20120.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 1998
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090620_20130.npz
# 1 2354
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090627_20160.npz
# 1 1982
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090630_20130.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 2765
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090633_20120.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 1903
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090636_20121.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 3091
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090615_20140.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 1863
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090625_20160.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 3187
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090621_20130.npz
# 1 2934
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090618_20161.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 2933
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090628_20150.npz
# 1 2146
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090631_20130.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 1586
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090634_20150.npz
# 1 1531
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090637_20140.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 1799
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090622_20150.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 3021
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090616_20140.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 2314
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090629_20120.npz
# 1 1693
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090632_20130.npz
# 1 1009
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090619_20121.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 3654
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090626_20160.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 2319
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090635_20140.npz
# 1 2730
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090638_20131.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 2119
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090639_20150.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 1259
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090642_20130.npz
# 1 1918
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090645_20141.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 1909
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090640_20140.npz
# 1 4845
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090643_20121.npz
# 1 2258
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090646_20120.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# 1 1377
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090641_20160.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# 1 1635
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_stage0/23090644_20131.npz
# not using nonzero mask for normalization
# Are we using the nonzero maks for normalizaion? OrderedDict([(0, False), (1, False)])
# the median shape of the dataset is  [299. 128. 128.]
# the max shape in the dataset is  [335. 128. 128.]
# the min shape in the dataset is  [263. 128. 128.]
# we don't want feature maps smaller than  4  in the bottleneck
# the transposed median shape of the dataset is  [299. 128. 128.]
# [{'batch_size': 202, 'num_pool_per_axis': [5, 5], 'patch_size': array([128, 128]), 'median_patient_size_in_voxels': array([299, 128, 128]), 'current_spacing': array([1., 1., 1.]), 'original_spacing': array([1., 1., 1.]), 'pool_op_kernel_sizes': [[2, 2], [2, 2], [2, 2], [2, 2], [2, 2]], 'conv_kernel_sizes': [[3, 3], [3, 3], [3, 3], [3, 3], [3, 3], [3, 3]], 'do_dummy_2D_data_aug': False}]
# Initializing to run preprocessing
# npz folder: /mnt/temp/nnUNet/nnunet/nnUNet_raw_data_base/nnUNet_cropped_data/Task555_PETCT
# output_folder: /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# normalization...
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# normalization done
# normalization done
# normalization done
# 1 1523
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090557_20130.npz
# normalization done
# normalization done
# normalization done
# 1 1576
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090571_20120.npz
# normalization done
# normalization done
# 1 2148
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090563_20151.npz
# 1 3800
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090560_20160.npz
# 1 2179
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090582_20150.npz
# 1 2186
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090579_20141.npz
# 1 3219
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090585_20130.npz
# 1 2130
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090567_20160.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 263, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 263, 128, 128)}
#
# normalization...
# normalization done
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# 1 1998
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090558_20120.npz
# normalization done
# 1 2276
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090572_20130.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# normalization...
# no resampling necessary
# no resampling necessary
# ...
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# normalization done
# 1 1770
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090607_20120.npz
# 1 3163
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090590_20121.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# normalization done
# 1 2867
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090596_20150.npz
# normalization done
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# 1 2984
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090603_20141.npz
# normalization done
# 1 1447
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090613_20130.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# normalization done
# 1 3219
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090610_20151.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# normalization done
# normalization done
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# normalization done
# 1 3220
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090614_20120.npz
# 1 2589
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090617_20140.npz
# normalization done
# 1 1998
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090620_20130.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# 1 2773
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090623_20120.npz
# normalization done
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# normalization done
# 1 2354
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090627_20160.npz
# 1 1982
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090630_20130.npz
# normalization done
# 1 2765
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090633_20120.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# normalization done
# 1 1903
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090636_20121.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# normalization done
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# 1 1863
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090625_20160.npz
# normalization done
# normalization done
# normalization done
# 1 2934
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090618_20161.npz
# 1 3091
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090615_20140.npz
# 1 3187
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090621_20130.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization done
# no resampling necessary
# no resampling necessary
# normalization...
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# 1 2933
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090628_20150.npz
# normalization done
# normalization done
# 1 1586
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090634_20150.npz
# 1 2146
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090631_20130.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# normalization done
# 1 1531
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090637_20140.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# normalization done
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# normalization...
# 1 1799
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090622_20150.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# normalization done
# normalization done
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# 1 3654
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090626_20160.npz
# normalization done
# no resampling necessary
# no resampling necessary
# 1 1009
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090619_20121.npz
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# normalization done
# 1 3021
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090616_20140.npz
# 1 2319
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090635_20140.npz
# normalization done
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# 1 2314
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090629_20120.npz
# normalization done
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# 1 1693
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090632_20130.npz
# normalization done
# 1 2730
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090638_20131.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# normalization done
# 1 2119
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090639_20150.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# normalization...
# normalization done
# normalization done
# 1 1259
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090642_20130.npz
# 1 1918
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090645_20141.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# normalization done
# normalization done
# 1 1909
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090640_20140.npz
# normalization done
# 1 2258
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090646_20120.npz
# 1 4845
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090643_20121.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 299, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 299, 128, 128)}
#
# normalization...
# normalization done
# 1 1377
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090641_20160.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (2, 335, 128, 128)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (2, 335, 128, 128)}
#
# normalization...
# normalization done
# 1 1635
# saving:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D_stage0/23090644_20131.npz

# %% [markdown]
# # 2. Training

# %%
# Model 1
os.chdir(main_dir)

# !nnUNet_train 2d nnUNetTrainerV2 555 all
# !nnUNet_train 3d_fullres nnUNetTrainerV2 555 all

os.chdir(base_dir)

# !nnUNet_predict -i /mnt/temp/nnUNet/nnunet/nnUNet_raw_data_base/nnUNet_raw_data/Task555_PETCT/imagesTs/ -o /mnt/backup/working/nnUNet/nnunet/nnUNet_Prediction_Results/Task555_PETCT/2d_CEGDL/ -t 577 -tr nnUNetTrainerV2_Loss_CEGDL -m 2d --disable_tta
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# ###############################################
# I am running the following nnUNet: 2d
# My trainer class is:  <class 'nnunet.training.network_training.nnUNetTrainerV2.nnUNetTrainerV2'>
# For that I will be using the following configuration:
# num_classes:  1
# modalities:  {0: 'CT', 1: 'PET'}
# use_mask_for_norm OrderedDict([(0, False), (1, False)])
# keep_only_largest_region None
# min_region_size_per_class None
# min_size_per_class None
# normalization_schemes OrderedDict([(0, 'CT'), (1, 'nonCT')])
# stages...
#
# stage:  0
# {'batch_size': 202, 'num_pool_per_axis': [5, 5], 'patch_size': array([128, 128]), 'median_patient_size_in_voxels': array([299, 128, 128]), 'current_spacing': array([1., 1., 1.]), 'original_spacing': array([1., 1., 1.]), 'pool_op_kernel_sizes': [[2, 2], [2, 2], [2, 2], [2, 2], [2, 2]], 'conv_kernel_sizes': [[3, 3], [3, 3], [3, 3], [3, 3], [3, 3], [3, 3]], 'do_dummy_2D_data_aug': False}
#
# I am using stage 0 from these plans
# I am using batch dice + CE loss
#
# I am using data from this folder:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1_2D
# ###############################################
# loading dataset
# loading all case properties
# unpacking dataset
# done
# 2021-10-22 05:44:19.818044: lr: 0.01
# using pin_memory on device 0
# using pin_memory on device 0
# 2021-10-22 05:44:31.441031: Unable to plot network architecture:
# 2021-10-22 05:44:31.573259: No module named 'hiddenlayer'
# 2021-10-22 05:44:31.700932:
# printing the network instead:
#
# 2021-10-22 05:44:31.873156: Generic_UNet(
#   (conv_blocks_localization): ModuleList(
#     (0): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv2d(960, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (instnorm): InstanceNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (instnorm): InstanceNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (1): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (instnorm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (instnorm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (2): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (instnorm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (instnorm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (3): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (instnorm): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (instnorm): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (4): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (instnorm): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (instnorm): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (conv_blocks_context): ModuleList(
#     (0): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv2d(2, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (instnorm): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (instnorm): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (1): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (instnorm): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (instnorm): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (2): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (instnorm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (instnorm): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (3): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (instnorm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (instnorm): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (4): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv2d(256, 480, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (instnorm): InstanceNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (instnorm): InstanceNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (5): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#             (instnorm): InstanceNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (instnorm): InstanceNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (td): ModuleList()
#   (tu): ModuleList(
#     (0): ConvTranspose2d(480, 480, kernel_size=(2, 2), stride=(2, 2), bias=False)
#     (1): ConvTranspose2d(480, 256, kernel_size=(2, 2), stride=(2, 2), bias=False)
#     (2): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2), bias=False)
#     (3): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2), bias=False)
#     (4): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2), bias=False)
#   )
#   (seg_outputs): ModuleList(
#     (0): Conv2d(480, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (2): Conv2d(128, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (3): Conv2d(64, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (4): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
# )
# 2021-10-22 05:44:32.029404:
#
# 2021-10-22 05:44:32.121050:
# epoch:  0
# 2021-10-22 05:47:37.537832: train loss : -0.2586
# 2021-10-22 05:47:50.757548: validation loss: -0.6484
# 2021-10-22 05:47:50.763555: Average global foreground Dice: [0.7232]
# 2021-10-22 05:47:50.770865: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 05:47:51.273213: lr: 0.00982
# 2021-10-22 05:47:51.295317: This epoch took 199.054435 s
#
# 2021-10-22 05:47:51.302308:
# epoch:  1
# 2021-10-22 05:50:45.468648: train loss : -0.6885
# 2021-10-22 05:50:58.192970: validation loss: -0.7902
# 2021-10-22 05:50:58.201177: Average global foreground Dice: [0.8137]
# 2021-10-22 05:50:58.208328: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 05:50:58.805734: lr: 0.009639
# 2021-10-22 05:50:58.862474: saving checkpoint...
# 2021-10-22 05:50:59.995258: done, saving took 1.17 seconds
# 2021-10-22 05:51:00.490393: This epoch took 189.180578 s
#
# 2021-10-22 05:51:00.500949:
# epoch:  2
# 2021-10-22 05:53:44.929593: train loss : -0.7744
# 2021-10-22 05:53:57.475463: validation loss: -0.8107
# 2021-10-22 05:53:57.481075: Average global foreground Dice: [0.8253]
# 2021-10-22 05:53:57.488950: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 05:53:58.105387: lr: 0.009458
# 2021-10-22 05:53:58.158148: saving checkpoint...
# 2021-10-22 05:53:59.319748: done, saving took 1.19 seconds
# 2021-10-22 05:53:59.825256: This epoch took 179.316569 s
#
# 2021-10-22 05:53:59.834671:
# epoch:  3
# 2021-10-22 05:56:50.384846: train loss : -0.7993
# 2021-10-22 05:57:03.612194: validation loss: -0.8369
# 2021-10-22 05:57:03.617771: Average global foreground Dice: [0.8488]
# 2021-10-22 05:57:03.625535: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 05:57:04.141931: lr: 0.009277
# 2021-10-22 05:57:04.188767: saving checkpoint...
# 2021-10-22 05:57:05.316389: done, saving took 1.15 seconds
# 2021-10-22 05:57:05.805539: This epoch took 185.964047 s
#
# 2021-10-22 05:57:05.815094:
# epoch:  4
# 2021-10-22 06:00:00.544997: train loss : -0.8134
# 2021-10-22 06:00:13.808413: validation loss: -0.8409
# 2021-10-22 06:00:13.814427: Average global foreground Dice: [0.8503]
# 2021-10-22 06:00:13.821273: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:00:14.430367: lr: 0.009095
# 2021-10-22 06:00:14.485606: saving checkpoint...
# 2021-10-22 06:00:15.632704: done, saving took 1.18 seconds
# 2021-10-22 06:00:16.125440: This epoch took 190.301933 s
#
# 2021-10-22 06:00:16.136876:
# epoch:  5
# 2021-10-22 06:03:11.309439: train loss : -0.8205
# 2021-10-22 06:03:24.513433: validation loss: -0.8454
# 2021-10-22 06:03:24.519088: Average global foreground Dice: [0.8557]
# 2021-10-22 06:03:24.528350: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:03:25.071988: lr: 0.008913
# 2021-10-22 06:03:25.114058: saving checkpoint...
# 2021-10-22 06:03:26.206897: done, saving took 1.11 seconds
# 2021-10-22 06:03:26.764287: This epoch took 190.618192 s
#
# 2021-10-22 06:03:26.775480:
# epoch:  6
# 2021-10-22 06:06:19.112601: train loss : -0.8263
# 2021-10-22 06:06:31.616390: validation loss: -0.8483
# 2021-10-22 06:06:31.622131: Average global foreground Dice: [0.8595]
# 2021-10-22 06:06:31.629675: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:06:32.158605: lr: 0.008731
# 2021-10-22 06:06:32.205357: saving checkpoint...
# 2021-10-22 06:06:33.407723: done, saving took 1.22 seconds
# 2021-10-22 06:06:33.920720: This epoch took 187.136841 s
#
# 2021-10-22 06:06:33.930506:
# epoch:  7
# 2021-10-22 06:09:18.457221: train loss : -0.8313
# 2021-10-22 06:09:31.142030: validation loss: -0.8564
# 2021-10-22 06:09:31.147055: Average global foreground Dice: [0.8659]
# 2021-10-22 06:09:31.155256: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:09:31.727311: lr: 0.008548
# 2021-10-22 06:09:31.787603: saving checkpoint...
# 2021-10-22 06:09:32.884290: done, saving took 1.13 seconds
# 2021-10-22 06:09:33.491472: This epoch took 179.553659 s
#
# 2021-10-22 06:09:33.502209:
# epoch:  8
# 2021-10-22 06:12:25.846820: train loss : -0.8365
# 2021-10-22 06:12:38.953732: validation loss: -0.8556
# 2021-10-22 06:12:38.959104: Average global foreground Dice: [0.864]
# 2021-10-22 06:12:38.966928: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:12:39.524641: lr: 0.008364
# 2021-10-22 06:12:39.581148: saving checkpoint...
# 2021-10-22 06:12:40.695653: done, saving took 1.15 seconds
# 2021-10-22 06:12:41.226249: This epoch took 187.715741 s
#
# 2021-10-22 06:12:41.236276:
# epoch:  9
# 2021-10-22 06:15:35.695674: train loss : -0.8404
# 2021-10-22 06:15:48.941128: validation loss: -0.8627
# 2021-10-22 06:15:48.948704: Average global foreground Dice: [0.8693]
# 2021-10-22 06:15:48.956217: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:15:49.542831: lr: 0.008181
# 2021-10-22 06:15:49.593438: saving checkpoint...
# 2021-10-22 06:15:50.778959: done, saving took 1.21 seconds
# 2021-10-22 06:15:51.267900: This epoch took 190.023627 s
#
# 2021-10-22 06:15:51.277432:
# epoch:  10
# 2021-10-22 06:18:45.238777: train loss : -0.8422
# 2021-10-22 06:18:58.437826: validation loss: -0.8669
# 2021-10-22 06:18:58.443833: Average global foreground Dice: [0.8736]
# 2021-10-22 06:18:58.452624: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:18:58.989627: lr: 0.007996
# 2021-10-22 06:18:59.034540: saving checkpoint...
# 2021-10-22 06:19:00.177346: done, saving took 1.16 seconds
# 2021-10-22 06:19:00.670344: This epoch took 189.384615 s
#
# 2021-10-22 06:19:00.680066:
# epoch:  11
# 2021-10-22 06:21:54.898600: train loss : -0.8445
# 2021-10-22 06:22:08.083906: validation loss: -0.8683
# 2021-10-22 06:22:08.089245: Average global foreground Dice: [0.8766]
# 2021-10-22 06:22:08.098087: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:22:08.631434: lr: 0.007811
# 2021-10-22 06:22:08.670501: saving checkpoint...
# 2021-10-22 06:22:09.776463: done, saving took 1.12 seconds
# 2021-10-22 06:22:10.287915: This epoch took 189.599505 s
#
# 2021-10-22 06:22:10.297726:
# epoch:  12
# 2021-10-22 06:25:04.702532: train loss : -0.8482
# 2021-10-22 06:25:17.932847: validation loss: -0.8722
# 2021-10-22 06:25:17.938551: Average global foreground Dice: [0.8785]
# 2021-10-22 06:25:17.946354: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:25:18.445988: lr: 0.007626
# 2021-10-22 06:25:18.505987: saving checkpoint...
# 2021-10-22 06:25:19.664459: done, saving took 1.18 seconds
# 2021-10-22 06:25:20.161532: This epoch took 189.856355 s
#
# 2021-10-22 06:25:20.184006:
# epoch:  13
# 2021-10-22 06:28:15.401270: train loss : -0.8495
# 2021-10-22 06:28:28.499410: validation loss: -0.8762
# 2021-10-22 06:28:28.505070: Average global foreground Dice: [0.8815]
# 2021-10-22 06:28:28.512309: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:28:29.097162: lr: 0.00744
# 2021-10-22 06:28:29.140954: saving checkpoint...
# 2021-10-22 06:28:30.303844: done, saving took 1.19 seconds
# 2021-10-22 06:28:30.815490: This epoch took 190.623595 s
#
# 2021-10-22 06:28:30.825496:
# epoch:  14
# 2021-10-22 06:31:25.138040: train loss : -0.8528
# 2021-10-22 06:31:38.291019: validation loss: -0.8736
# 2021-10-22 06:31:38.296667: Average global foreground Dice: [0.879]
# 2021-10-22 06:31:38.305263: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:31:38.809823: lr: 0.007254
# 2021-10-22 06:31:38.865829: saving checkpoint...
# 2021-10-22 06:31:39.997786: done, saving took 1.15 seconds
# 2021-10-22 06:31:40.498476: This epoch took 189.664389 s
#
# 2021-10-22 06:31:40.520364:
# epoch:  15
# 2021-10-22 06:34:35.356242: train loss : -0.8551
# 2021-10-22 06:34:48.457181: validation loss: -0.8788
# 2021-10-22 06:34:48.462097: Average global foreground Dice: [0.8851]
# 2021-10-22 06:34:48.470246: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:34:49.047078: lr: 0.007067
# 2021-10-22 06:34:49.110533: saving checkpoint...
# 2021-10-22 06:34:50.285544: done, saving took 1.20 seconds
# 2021-10-22 06:34:50.823055: This epoch took 190.294198 s
#
# 2021-10-22 06:34:50.842324:
# epoch:  16
# 2021-10-22 06:37:44.838095: train loss : -0.8561
# 2021-10-22 06:37:58.059332: validation loss: -0.8773
# 2021-10-22 06:37:58.064634: Average global foreground Dice: [0.8829]
# 2021-10-22 06:37:58.071798: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:37:58.635008: lr: 0.00688
# 2021-10-22 06:37:58.693707: saving checkpoint...
# 2021-10-22 06:37:59.855248: done, saving took 1.19 seconds
# 2021-10-22 06:38:00.350313: This epoch took 189.499932 s
#
# 2021-10-22 06:38:00.370528:
# epoch:  17
# 2021-10-22 06:40:55.514731: train loss : -0.8577
# 2021-10-22 06:41:08.759148: validation loss: -0.8803
# 2021-10-22 06:41:08.767173: Average global foreground Dice: [0.8849]
# 2021-10-22 06:41:08.775246: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:41:09.341524: lr: 0.006692
# 2021-10-22 06:41:09.411757: saving checkpoint...
# 2021-10-22 06:41:10.519533: done, saving took 1.14 seconds
# 2021-10-22 06:41:11.031074: This epoch took 190.651716 s
#
# 2021-10-22 06:41:11.052090:
# epoch:  18
# 2021-10-22 06:44:05.981230: train loss : -0.8584
# 2021-10-22 06:44:19.146874: validation loss: -0.8829
# 2021-10-22 06:44:19.153849: Average global foreground Dice: [0.8884]
# 2021-10-22 06:44:19.161592: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:44:19.710251: lr: 0.006504
# 2021-10-22 06:44:19.769698: saving checkpoint...
# 2021-10-22 06:44:20.979459: done, saving took 1.24 seconds
# 2021-10-22 06:44:21.489094: This epoch took 190.428813 s
#
# 2021-10-22 06:44:21.509480:
# epoch:  19
# 2021-10-22 06:47:16.475324: train loss : -0.8623
# 2021-10-22 06:47:29.621669: validation loss: -0.8839
# 2021-10-22 06:47:29.626328: Average global foreground Dice: [0.8883]
# 2021-10-22 06:47:29.647798: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:47:30.207159: lr: 0.006314
# 2021-10-22 06:47:30.260475: saving checkpoint...
# 2021-10-22 06:47:31.427937: done, saving took 1.19 seconds
# 2021-10-22 06:47:31.933428: This epoch took 190.416059 s
#
# 2021-10-22 06:47:31.971178:
# epoch:  20
# 2021-10-22 06:50:26.899708: train loss : -0.8634
# 2021-10-22 06:50:39.993745: validation loss: -0.8866
# 2021-10-22 06:50:40.000204: Average global foreground Dice: [0.8917]
# 2021-10-22 06:50:40.008176: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:50:40.517937: lr: 0.006125
# 2021-10-22 06:50:40.589134: saving checkpoint...
# 2021-10-22 06:50:41.736529: done, saving took 1.18 seconds
# 2021-10-22 06:50:42.212949: This epoch took 190.232933 s
#
# 2021-10-22 06:50:42.234653:
# epoch:  21
# 2021-10-22 06:53:27.516251: train loss : -0.8650
# 2021-10-22 06:53:40.167750: validation loss: -0.8888
# 2021-10-22 06:53:40.173329: Average global foreground Dice: [0.8929]
# 2021-10-22 06:53:40.181157: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:53:40.843508: lr: 0.005934
# 2021-10-22 06:53:40.899298: saving checkpoint...
# 2021-10-22 06:53:42.106250: done, saving took 1.23 seconds
# 2021-10-22 06:53:42.640761: This epoch took 180.397761 s
#
# 2021-10-22 06:53:42.660920:
# epoch:  22
# 2021-10-22 06:56:32.740665: train loss : -0.8658
# 2021-10-22 06:56:45.976902: validation loss: -0.8900
# 2021-10-22 06:56:45.981957: Average global foreground Dice: [0.894]
# 2021-10-22 06:56:45.989549: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:56:46.557638: lr: 0.005743
# 2021-10-22 06:56:46.609284: saving checkpoint...
# 2021-10-22 06:56:47.710744: done, saving took 1.12 seconds
# 2021-10-22 06:56:48.248226: This epoch took 185.579744 s
#
# 2021-10-22 06:56:48.269792:
# epoch:  23
# 2021-10-22 06:59:43.080693: train loss : -0.8671
# 2021-10-22 06:59:56.248273: validation loss: -0.8914
# 2021-10-22 06:59:56.254232: Average global foreground Dice: [0.8944]
# 2021-10-22 06:59:56.263110: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 06:59:56.785286: lr: 0.005551
# 2021-10-22 06:59:56.840939: saving checkpoint...
# 2021-10-22 06:59:57.963181: done, saving took 1.15 seconds
# 2021-10-22 06:59:58.450953: This epoch took 190.173450 s
#
# 2021-10-22 06:59:58.473440:
# epoch:  24
# 2021-10-22 07:02:53.822426: train loss : -0.8675
# 2021-10-22 07:03:07.032117: validation loss: -0.8904
# 2021-10-22 07:03:07.038332: Average global foreground Dice: [0.8934]
# 2021-10-22 07:03:07.046865: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:03:07.607486: lr: 0.005359
# 2021-10-22 07:03:07.692712: saving checkpoint...
# 2021-10-22 07:03:08.836062: done, saving took 1.19 seconds
# 2021-10-22 07:03:09.301499: This epoch took 190.819419 s
#
# 2021-10-22 07:03:09.320006:
# epoch:  25
# 2021-10-22 07:06:03.897525: train loss : -0.8685
# 2021-10-22 07:06:16.532327: validation loss: -0.8934
# 2021-10-22 07:06:16.537780: Average global foreground Dice: [0.8973]
# 2021-10-22 07:06:16.544660: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:06:17.125637: lr: 0.005166
# 2021-10-22 07:06:17.196848: saving checkpoint...
# 2021-10-22 07:06:18.337253: done, saving took 1.18 seconds
# 2021-10-22 07:06:18.826292: This epoch took 189.497730 s
#
# 2021-10-22 07:06:18.846126:
# epoch:  26
# 2021-10-22 07:09:04.048001: train loss : -0.8715
# 2021-10-22 07:09:16.674891: validation loss: -0.8967
# 2021-10-22 07:09:16.680481: Average global foreground Dice: [0.8993]
# 2021-10-22 07:09:16.689033: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:09:17.283444: lr: 0.004971
# 2021-10-22 07:09:17.347601: saving checkpoint...
# 2021-10-22 07:09:18.473044: done, saving took 1.16 seconds
# 2021-10-22 07:09:18.978799: This epoch took 180.124570 s
#
# 2021-10-22 07:09:18.998700:
# epoch:  27
# 2021-10-22 07:12:11.584111: train loss : -0.8717
# 2021-10-22 07:12:24.835900: validation loss: -0.8960
# 2021-10-22 07:12:24.841526: Average global foreground Dice: [0.8981]
# 2021-10-22 07:12:24.849165: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:12:25.401922: lr: 0.004776
# 2021-10-22 07:12:25.455677: saving checkpoint...
# 2021-10-22 07:12:26.593827: done, saving took 1.16 seconds
# 2021-10-22 07:12:27.084190: This epoch took 188.077555 s
#
# 2021-10-22 07:12:27.106748:
# epoch:  28
# 2021-10-22 07:15:22.761751: train loss : -0.8727
# 2021-10-22 07:15:35.989895: validation loss: -0.8970
# 2021-10-22 07:15:35.995245: Average global foreground Dice: [0.9002]
# 2021-10-22 07:15:36.003331: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:15:36.543717: lr: 0.004581
# 2021-10-22 07:15:36.599569: saving checkpoint...
# 2021-10-22 07:15:37.696985: done, saving took 1.12 seconds
# 2021-10-22 07:15:38.190300: This epoch took 191.075024 s
#
# 2021-10-22 07:15:38.212069:
# epoch:  29
# 2021-10-22 07:18:34.046402: train loss : -0.8738
# 2021-10-22 07:18:47.250499: validation loss: -0.9002
# 2021-10-22 07:18:47.257385: Average global foreground Dice: [0.9024]
# 2021-10-22 07:18:47.265077: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:18:47.830273: lr: 0.004384
# 2021-10-22 07:18:47.887357: saving checkpoint...
# 2021-10-22 07:18:49.077409: done, saving took 1.21 seconds
# 2021-10-22 07:18:49.556537: This epoch took 191.336287 s
#
# 2021-10-22 07:18:49.576685:
# epoch:  30
# 2021-10-22 07:21:42.264459: train loss : -0.8744
# 2021-10-22 07:21:54.798107: validation loss: -0.9005
# 2021-10-22 07:21:54.803570: Average global foreground Dice: [0.9032]
# 2021-10-22 07:21:54.811600: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:21:55.390441: lr: 0.004186
# 2021-10-22 07:21:55.464680: saving checkpoint...
# 2021-10-22 07:21:56.628062: done, saving took 1.20 seconds
# 2021-10-22 07:21:57.128385: This epoch took 187.544507 s
#
# 2021-10-22 07:21:57.150939:
# epoch:  31
# 2021-10-22 07:24:42.846226: train loss : -0.8755
# 2021-10-22 07:24:55.547134: validation loss: -0.8985
# 2021-10-22 07:24:55.552928: Average global foreground Dice: [0.9014]
# 2021-10-22 07:24:55.560338: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:24:56.066413: lr: 0.003987
# 2021-10-22 07:24:56.134556: saving checkpoint...
# 2021-10-22 07:24:57.277751: done, saving took 1.18 seconds
# 2021-10-22 07:24:57.774373: This epoch took 180.616223 s
#
# 2021-10-22 07:24:57.794674:
# epoch:  32
# 2021-10-22 07:27:52.689153: train loss : -0.8760
# 2021-10-22 07:28:05.944247: validation loss: -0.9033
# 2021-10-22 07:28:05.951756: Average global foreground Dice: [0.905]
# 2021-10-22 07:28:05.958627: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:28:06.535145: lr: 0.003787
# 2021-10-22 07:28:06.606171: saving checkpoint...
# 2021-10-22 07:28:07.732570: done, saving took 1.16 seconds
# 2021-10-22 07:28:08.246643: This epoch took 190.443936 s
#
# 2021-10-22 07:28:08.267256:
# epoch:  33
# 2021-10-22 07:31:03.724973: train loss : -0.8781
# 2021-10-22 07:31:16.926567: validation loss: -0.9054
# 2021-10-22 07:31:16.932909: Average global foreground Dice: [0.9068]
# 2021-10-22 07:31:16.940571: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:31:17.492124: lr: 0.003586
# 2021-10-22 07:31:17.559932: saving checkpoint...
# 2021-10-22 07:31:18.703462: done, saving took 1.18 seconds
# 2021-10-22 07:31:19.184830: This epoch took 190.910375 s
#
# 2021-10-22 07:31:19.206125:
# epoch:  34
# 2021-10-22 07:34:15.625212: train loss : -0.8798
# 2021-10-22 07:34:28.848690: validation loss: -0.9028
# 2021-10-22 07:34:28.856270: Average global foreground Dice: [0.9045]
# 2021-10-22 07:34:28.868576: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:34:29.391339: lr: 0.003384
# 2021-10-22 07:34:29.458810: saving checkpoint...
# 2021-10-22 07:34:30.588817: done, saving took 1.17 seconds
# 2021-10-22 07:34:31.066941: This epoch took 191.852687 s
#
# 2021-10-22 07:34:31.087121:
# epoch:  35
# 2021-10-22 07:37:26.645866: train loss : -0.8796
# 2021-10-22 07:37:39.825815: validation loss: -0.9040
# 2021-10-22 07:37:39.830873: Average global foreground Dice: [0.9049]
# 2021-10-22 07:37:39.837964: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:37:40.357394: lr: 0.00318
# 2021-10-22 07:37:40.427337: saving checkpoint...
# 2021-10-22 07:37:41.617905: done, saving took 1.23 seconds
# 2021-10-22 07:37:42.138664: This epoch took 191.043225 s
#
# 2021-10-22 07:37:42.161268:
# epoch:  36
# 2021-10-22 07:40:38.094625: train loss : -0.8805
# 2021-10-22 07:40:51.204178: validation loss: -0.9066
# 2021-10-22 07:40:51.209622: Average global foreground Dice: [0.9079]
# 2021-10-22 07:40:51.217414: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:40:51.749132: lr: 0.002975
# 2021-10-22 07:40:51.821851: saving checkpoint...
# 2021-10-22 07:40:52.952420: done, saving took 1.17 seconds
# 2021-10-22 07:40:53.449530: This epoch took 191.272813 s
#
# 2021-10-22 07:40:53.469878:
# epoch:  37
# 2021-10-22 07:43:49.301183: train loss : -0.8820
# 2021-10-22 07:44:02.498479: validation loss: -0.9070
# 2021-10-22 07:44:02.503514: Average global foreground Dice: [0.9074]
# 2021-10-22 07:44:02.510970: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:44:03.087498: lr: 0.002768
# 2021-10-22 07:44:03.157388: saving checkpoint...
# 2021-10-22 07:44:04.289074: done, saving took 1.17 seconds
# 2021-10-22 07:44:04.776193: This epoch took 191.297796 s
#
# 2021-10-22 07:44:04.797606:
# epoch:  38
# 2021-10-22 07:47:00.270893: train loss : -0.8826
# 2021-10-22 07:47:13.463824: validation loss: -0.9101
# 2021-10-22 07:47:13.469662: Average global foreground Dice: [0.911]
# 2021-10-22 07:47:13.477365: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:47:14.045519: lr: 0.00256
# 2021-10-22 07:47:14.111272: saving checkpoint...
# 2021-10-22 07:47:15.294200: done, saving took 1.22 seconds
# 2021-10-22 07:47:15.875146: This epoch took 191.069053 s
#
# 2021-10-22 07:47:15.890963:
# epoch:  39
# 2021-10-22 07:50:11.460675: train loss : -0.8848
# 2021-10-22 07:50:24.661948: validation loss: -0.9116
# 2021-10-22 07:50:24.666906: Average global foreground Dice: [0.9128]
# 2021-10-22 07:50:24.674736: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:50:25.184855: lr: 0.002349
# 2021-10-22 07:50:25.255542: saving checkpoint...
# 2021-10-22 07:50:26.406079: done, saving took 1.19 seconds
# 2021-10-22 07:50:26.897730: This epoch took 190.998950 s
#
# 2021-10-22 07:50:26.919522:
# epoch:  40
# /mnt/backup/nnUNet/nnunet/training/network_training/nnUNetTrainerV2.py:254: FutureWarning: Non-finite norm encountered in torch.nn.utils.clip_grad_norm_; continuing anyway. Note that the default behavior will change in a future release to error out if a non-finite total norm is encountered. At that point, setting error_if_nonfinite=false will be required to retain the old behavior.
#   torch.nn.utils.clip_grad_norm_(self.network.parameters(), 12)
# 2021-10-22 07:53:22.560811: train loss : -0.8851
# 2021-10-22 07:53:35.783641: validation loss: -0.9144
# 2021-10-22 07:53:35.789596: Average global foreground Dice: [0.9136]
# 2021-10-22 07:53:35.797301: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:53:36.364577: lr: 0.002137
# 2021-10-22 07:53:36.419309: saving checkpoint...
# 2021-10-22 07:53:37.518806: done, saving took 1.14 seconds
# 2021-10-22 07:53:38.012338: This epoch took 191.082441 s
#
# 2021-10-22 07:53:38.024149:
# epoch:  41
# 2021-10-22 07:56:33.339160: train loss : -0.8858
# 2021-10-22 07:56:46.513962: validation loss: -0.9121
# 2021-10-22 07:56:46.519917: Average global foreground Dice: [0.913]
# 2021-10-22 07:56:46.527860: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:56:47.041763: lr: 0.001922
# 2021-10-22 07:56:47.096808: saving checkpoint...
# 2021-10-22 07:56:48.203032: done, saving took 1.14 seconds
# 2021-10-22 07:56:48.962732: This epoch took 190.931527 s
#
# 2021-10-22 07:56:48.972201:
# epoch:  42
# 2021-10-22 07:59:45.125509: train loss : -0.8865
# 2021-10-22 07:59:58.312405: validation loss: -0.9136
# 2021-10-22 07:59:58.317665: Average global foreground Dice: [0.9141]
# 2021-10-22 07:59:58.325108: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 07:59:58.872062: lr: 0.001704
# 2021-10-22 07:59:58.913332: saving checkpoint...
# 2021-10-22 08:00:00.042915: done, saving took 1.15 seconds
# 2021-10-22 08:00:00.556495: This epoch took 191.575041 s
#
# 2021-10-22 08:00:00.568358:
# epoch:  43
# 2021-10-22 08:02:48.828125: train loss : -0.8875
# 2021-10-22 08:03:01.360386: validation loss: -0.9146
# 2021-10-22 08:03:01.365708: Average global foreground Dice: [0.9145]
# 2021-10-22 08:03:01.374765: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 08:03:01.914393: lr: 0.001483
# 2021-10-22 08:03:01.959642: saving checkpoint...
# 2021-10-22 08:03:03.090182: done, saving took 1.15 seconds
# 2021-10-22 08:03:03.636497: This epoch took 183.059806 s
#
# 2021-10-22 08:03:03.645931:
# epoch:  44
# 2021-10-22 08:05:51.911112: train loss : -0.8889
# 2021-10-22 08:06:04.998447: validation loss: -0.9176
# 2021-10-22 08:06:05.004062: Average global foreground Dice: [0.9168]
# 2021-10-22 08:06:05.012634: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 08:06:05.518246: lr: 0.001259
# 2021-10-22 08:06:05.564393: saving checkpoint...
# 2021-10-22 08:06:06.740907: done, saving took 1.20 seconds
# 2021-10-22 08:06:07.284929: This epoch took 183.632024 s
#
# 2021-10-22 08:06:07.294780:
# epoch:  45
# 2021-10-22 08:09:03.137139: train loss : -0.8890
# 2021-10-22 08:09:16.314506: validation loss: -0.9161
# 2021-10-22 08:09:16.320929: Average global foreground Dice: [0.9157]
# 2021-10-22 08:09:16.329628: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 08:09:16.900400: lr: 0.00103
# 2021-10-22 08:09:16.954938: saving checkpoint...
# 2021-10-22 08:09:18.093962: done, saving took 1.16 seconds
# 2021-10-22 08:09:18.588444: This epoch took 191.284336 s
#
# 2021-10-22 08:09:18.598346:
# epoch:  46
# 2021-10-22 08:12:14.323829: train loss : -0.8911
# 2021-10-22 08:12:27.485663: validation loss: -0.9186
# 2021-10-22 08:12:27.490793: Average global foreground Dice: [0.9183]
# 2021-10-22 08:12:27.499217: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 08:12:28.057789: lr: 0.000795
# 2021-10-22 08:12:28.100339: saving checkpoint...
# 2021-10-22 08:12:29.227808: done, saving took 1.15 seconds
# 2021-10-22 08:12:29.729467: This epoch took 191.123491 s
#
# 2021-10-22 08:12:29.739141:
# epoch:  47
# 2021-10-22 08:15:24.401653: train loss : -0.8921
# 2021-10-22 08:15:37.546640: validation loss: -0.9196
# 2021-10-22 08:15:37.551823: Average global foreground Dice: [0.9184]
# 2021-10-22 08:15:37.562475: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 08:15:38.178382: lr: 0.000552
# 2021-10-22 08:15:38.218565: saving checkpoint...
# 2021-10-22 08:15:39.366091: done, saving took 1.17 seconds
# 2021-10-22 08:15:39.855026: This epoch took 190.107908 s
#
# 2021-10-22 08:15:39.864380:
# epoch:  48
# 2021-10-22 08:18:35.742337: train loss : -0.8919
# 2021-10-22 08:18:48.958141: validation loss: -0.9206
# 2021-10-22 08:18:48.962980: Average global foreground Dice: [0.9197]
# 2021-10-22 08:18:48.970994: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 08:18:49.526670: lr: 0.000296
# 2021-10-22 08:18:49.570747: saving checkpoint...
# 2021-10-22 08:18:50.707174: done, saving took 1.16 seconds
# 2021-10-22 08:18:51.192521: This epoch took 191.319507 s
#
# 2021-10-22 08:18:51.214592:
# epoch:  49
# 2021-10-22 08:21:44.143794: train loss : -0.8933
# 2021-10-22 08:21:56.643182: validation loss: -0.9232
# 2021-10-22 08:21:56.648617: Average global foreground Dice: [0.9217]
# 2021-10-22 08:21:56.656322: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-22 08:21:57.227981: lr: 0.0
# 2021-10-22 08:21:57.253327: saving scheduled checkpoint file...
# 2021-10-22 08:21:57.280023: saving checkpoint...
# 2021-10-22 08:21:58.262652: done, saving took 1.00 seconds
# 2021-10-22 08:21:58.745464: done
# 2021-10-22 08:21:58.774233: saving checkpoint...
# 2021-10-22 08:21:59.899913: done, saving took 1.14 seconds
# 2021-10-22 08:22:00.889508: This epoch took 189.666556 s
#
# 2021-10-22 08:22:00.918411: saving checkpoint...
# 2021-10-22 08:22:02.050050: done, saving took 1.15 seconds
# 23090557_20130 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090558_20120 (3, 263, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090559_20150 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090560_20160 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090561_20120 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090562_20140 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090563_20151 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090564_20130 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090566_20141 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090567_20160 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090568_20121 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090569_20120 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090571_20120 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090572_20130 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090578_20120 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090579_20141 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090580_20131 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090581_20130 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090582_20150 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090583_20160 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090584_20120 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090585_20130 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090586_20120 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090587_20150 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090588_20131 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090589_20140 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090590_20121 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090591_20140 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090592_20130 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090593_20120 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090594_20160 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090595_20121 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090596_20150 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090597_20130 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090598_20130 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090599_20140 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090600_20121 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090601_20130 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090603_20141 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090604_20140 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090606_20120 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090607_20120 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090608_20120 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090609_20120 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090610_20151 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090611_20150 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090612_20121 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090613_20130 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090614_20120 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090615_20140 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090616_20140 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090617_20140 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090618_20161 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090619_20121 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090620_20130 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090621_20130 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090622_20150 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090623_20120 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090625_20160 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090626_20160 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090627_20160 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090628_20150 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090629_20120 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090630_20130 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090631_20130 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090632_20130 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1)
# ...
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090600_20121 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090601_20130 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090603_20141 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090604_20140 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090606_20120 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090607_20120 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090608_20120 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090609_20120 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090610_20151 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090611_20150 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090612_20121 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090613_20130 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090614_20120 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090615_20140 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090616_20140 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090617_20140 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090618_20161 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090619_20121 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090620_20130 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090621_20130 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090622_20150 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090623_20120 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090625_20160 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090626_20160 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090627_20160 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090628_20150 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090629_20120 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090630_20130 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090631_20130 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090632_20130 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090633_20120 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090634_20150 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090635_20140 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090636_20121 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090637_20140 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090638_20131 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090639_20150 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090640_20140 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090641_20160 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090642_20130 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090643_20121 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090644_20131 (3, 335, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 335, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 79], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090645_20141 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 23090646_20120 (3, 299, 128, 128)
# debug: mirroring True mirror_axes (0, 1, 2)
# step_size: 0.5
# do mirror: True
# data shape: (2, 299, 128, 128)
# patch size: [256  96  96]
# steps (x, y, and z): [[0, 43], [0, 32], [0, 32]]
# number of tiles: 8
# using precomputed Gaussian
# prediction done
# force_separate_z: None interpolation order: 1
# no resampling necessary
# 2021-10-22 13:13:27.732817: finished prediction
# 2021-10-22 13:13:27.741743: evaluation of raw predictions
# 2021-10-22 13:13:34.568434: determining postprocessing
# Foreground vs background
# before: 0.8801634855655209
# after:  0.8801701240698341
# Removing all but the largest foreground region improved results!
# for_which_classes [1]
# min_valid_object_sizes None
# Only one class present, no need to do each class separately as this is covered in fg vs bg
# done
# for which classes:
# [[1]]
# min_object_sizes
# None
# done

# %%
# Model 2
os.chdir(main_dir)

# !nnUNet_train 3d_fullres nnUNetTrainerV2 555 all

os.chdir(base_dir)
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# ###############################################
# I am running the following nnUNet: 3d_fullres
# My trainer class is:  <class 'nnunet.training.network_training.nnUNetTrainerV2.nnUNetTrainerV2'>
# For that I will be using the following configuration:
# num_classes:  1
# modalities:  {0: 'CT', 1: 'PET'}
# use_mask_for_norm OrderedDict([(0, False), (1, False)])
# keep_only_largest_region None
# min_region_size_per_class None
# min_size_per_class None
# normalization_schemes OrderedDict([(0, 'CT'), (1, 'nonCT')])
# stages...
#
# stage:  0
# {'batch_size': 2, 'num_pool_per_axis': [5, 4, 4], 'patch_size': array([192, 112, 112]), 'median_patient_size_in_voxels': array([284, 174, 173]), 'current_spacing': array([1., 1., 1.]), 'original_spacing': array([1., 1., 1.]), 'do_dummy_2D_data_aug': False, 'pool_op_kernel_sizes': [[2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 1, 1]], 'conv_kernel_sizes': [[3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]]}
#
# I am using stage 0 from these plans
# I am using sample dice + CE loss
#
# I am using data from this folder:  /mnt/temp/nnUNet/nnunet/preprocessed/Task555_PETCT/nnUNetData_plans_v2.1
# ###############################################
# loading dataset
# loading all case properties
# unpacking dataset
# done
# 2021-10-20 03:33:49.078931: lr: 0.01
# using pin_memory on device 0
# using pin_memory on device 0
# 2021-10-20 03:34:07.260241: Unable to plot network architecture:
# 2021-10-20 03:34:07.404581: No module named 'hiddenlayer'
# 2021-10-20 03:34:07.604616:
# printing the network instead:
#
# 2021-10-20 03:34:07.712244: Generic_UNet(
#   (conv_blocks_localization): ModuleList(
#     (0): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(640, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (1): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(512, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (2): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(256, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (3): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (4): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (conv_blocks_context): ModuleList(
#     (0): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(2, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (1): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (2): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (3): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (4): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(256, 320, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (5): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(2, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (td): ModuleList()
#   (tu): ModuleList(
#     (0): ConvTranspose3d(320, 320, kernel_size=(2, 1, 1), stride=(2, 1, 1), bias=False)
#     (1): ConvTranspose3d(320, 256, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     (2): ConvTranspose3d(256, 128, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     (3): ConvTranspose3d(128, 64, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     (4): ConvTranspose3d(64, 32, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#   )
#   (seg_outputs): ModuleList(
#     (0): Conv3d(320, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (1): Conv3d(256, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (2): Conv3d(128, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (3): Conv3d(64, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (4): Conv3d(32, 2, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   )
# )
# 2021-10-20 03:34:07.841814:
#
# 2021-10-20 03:34:07.948309:
# epoch:  0
# 2021-10-20 03:39:48.642770: train loss : -0.2245
# 2021-10-20 03:40:11.036680: validation loss: -0.6533
# 2021-10-20 03:40:11.248775: Average global foreground Dice: [0.6926]
# 2021-10-20 03:40:11.368213: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-20 03:40:14.436785: lr: 0.00982
# 2021-10-20 03:40:14.652274: This epoch took 366.519958 s
#
# 2021-10-20 03:40:14.759811:
# epoch:  1
# 2021-10-20 03:45:02.467546: train loss : -0.6569
# 2021-10-20 03:45:23.927424: validation loss: -0.7596
# 2021-10-20 03:45:23.937129: Average global foreground Dice: [0.7919]
# 2021-10-20 03:45:23.943074: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-20 03:45:24.766518: lr: 0.009639
# 2021-10-20 03:45:24.876301: saving checkpoint...
# 2021-10-20 03:45:26.412023: done, saving took 1.61 seconds
# 2021-10-20 03:45:28.086648: This epoch took 313.226288 s
#
# 2021-10-20 03:45:28.091976:
# epoch:  2
# 2021-10-20 03:50:21.174462: train loss : -0.7406
# 2021-10-20 03:50:43.441890: validation loss: -0.8068
# 2021-10-20 03:50:43.812645: Average global foreground Dice: [0.8431]
# 2021-10-20 03:50:43.964268: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-20 03:50:47.637108: lr: 0.009458
# 2021-10-20 03:50:48.162342: saving checkpoint...
# 2021-10-20 03:50:50.755469: done, saving took 2.80 seconds
# 2021-10-20 03:50:52.438457: This epoch took 324.340608 s
#
# 2021-10-20 03:50:52.444056:
# epoch:  3
# 2021-10-20 03:55:53.633903: train loss : -0.7778
# 2021-10-20 03:56:16.512150: validation loss: -0.8340
# 2021-10-20 03:56:16.805053: Average global foreground Dice: [0.8608]
# 2021-10-20 03:56:17.036202: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-20 03:56:21.166214: lr: 0.009277
# 2021-10-20 03:56:21.640540: saving checkpoint...
# 2021-10-20 03:56:27.279438: done, saving took 5.86 seconds
# 2021-10-20 03:56:28.947689: This epoch took 336.498307 s
#
# 2021-10-20 03:56:28.952572:
# epoch:  4
# 2021-10-20 04:01:16.217691: train loss : -0.8073
# 2021-10-20 04:01:36.941293: validation loss: -0.8496
# 2021-10-20 04:01:37.204902: Average global foreground Dice: [0.8785]
# 2021-10-20 04:01:37.404516: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-20 04:01:39.417551: lr: 0.009095
# 2021-10-20 04:01:39.545457: saving checkpoint...
# 2021-10-20 04:01:41.349027: done, saving took 1.90 seconds
# 2021-10-20 04:01:43.050029: This epoch took 314.092450 s
#
# 2021-10-20 04:01:43.056251:
# epoch:  5
# 2021-10-20 04:06:19.063956: train loss : -0.8362
# 2021-10-20 04:06:41.582815: validation loss: -0.8758
# 2021-10-20 04:06:42.040667: Average global foreground Dice: [0.8951]
# 2021-10-20 04:06:42.164218: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2021-10-20 04:06:45.924876: lr: 0.008913
# 2021-10-20 04:06:46.570220: saving checkpoint...
# 2021-10-20 04:06:48.330597: done, saving took 1.93 seconds
# 2021-10-20 04:06:50.011959: This epoch took 306.950011 s
#
# 2021-10-20 04:06:50.017918:
# epoch:  6

# %%
model_1 = os.path.join(model_dir, 'nnUNet/2d/')
# fold_list = ['fold_0', 'fold_1', 'fold_2', 'fold_3', 'fold_4']
fold_list = [fold_0, fold_1, fold_2, fold_3, fold_4]

fold_all = os.path.join(model_1, 'Task555_PETCT/nnUNetTrainerV2__nnUNetPlansv2.1/all')
fold_0 = os.path.join(model_1, 'Task555_PETCT/nnUNetTrainerV2__nnUNetPlansv2.1/fold_0')
fold_1 = os.path.join(model_1, 'Task555_PETCT/nnUNetTrainerV2__nnUNetPlansv2.1/fold_1')
fold_2 = os.path.join(model_1, 'Task555_PETCT/nnUNetTrainerV2__nnUNetPlansv2.1/fold_2')
fold_3 = os.path.join(model_1, 'Task555_PETCT/nnUNetTrainerV2__nnUNetPlansv2.1/fold_3')
fold_4 = os.path.join(model_1, 'Task555_PETCT/nnUNetTrainerV2__nnUNetPlansv2.1/fold_4')

# %%
for fold in fold_list:
    if os.path.exists(fold):
        shutil.rmtree(fold)
    else:
        shutil.copytree(fold_all, fold)
# Out:
# exists

# %%
os.chdir('/tf')

# %%
task_dir
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-01a90211ad26> in <module>
# ----> 1 task_dir
#
# NameError: name 'task_dir' is not defined

# %%
os.getcwd()
# Out:
# '/mnt/backup/working'

# %%
os.listdir('/mnt/dataset')
# Out:
# ['23090580_20131226.hdf5',
#  '23090618_20161212.hdf5',
#  '23090628_20150204.hdf5',
#  '23090643_20121227.hdf5',
#  '23090644_20131216.hdf5',
#  '23090636_20121018.hdf5',
#  '23090585_20130213.hdf5',
#  '23090572_20130226.hdf5',
#  '23090603_20141212.hdf5',
#  '23090601_20130225.hdf5',
#  '23090569_20120607.hdf5',
#  '23090599_20140701.hdf5',
#  '23090597_20130227.hdf5',
#  '23090627_20160608.hdf5',
#  '23090559_20150812.hdf5',
#  '23090614_20120402.hdf5',
#  '23090557_20130717.hdf5',
#  '23090634_20150409.hdf5',
#  '23090581_20130626.hdf5',
#  '23090626_20160119.hdf5',
#  '23090568_20121018.hdf5',
#  '23090623_20120406.hdf5',
#  '23090615_20140403.hdf5',
#  '23090640_20140711.hdf5',
#  '23090613_20130208.hdf5',
#  '23090641_20160510.hdf5',
#  '23090609_20120510.hdf5',
#  '23090560_20160114.hdf5',
#  '23090563_20151216.hdf5',
#  '23090596_20150112.hdf5',
#  '23090632_20130807.hdf5',
#  '23090598_20130103.hdf5',
#  '23090584_20120523.hdf5',
#  '23090633_20120403.hdf5',
#  '23090607_20120420.hdf5',
#  '23090594_20160706.hdf5',
#  '23090622_20150105.hdf5',
#  '23090583_20160308.hdf5',
#  '23090637_20140401.hdf5',
#  '23090620_20130617.hdf5',
#  '23090645_20141212.hdf5',
#  '23090621_20130409.hdf5',
#  '23090562_20140206.hdf5',
#  '23090582_20150401.hdf5',
#  '23090566_20141114.hdf5',
#  '23090571_20120517.hdf5',
#  '23090642_20130409.hdf5',
#  '23090595_20121015.hdf5',
#  '23090586_20120627.hdf5',
#  '23090604_20140303.hdf5',
#  '23090561_20120330.hdf5',
#  '23090610_20151210.hdf5',
#  '23090639_20150522.hdf5',
#  '23090608_20120718.hdf5',
#  '23090588_20131025.hdf5',
#  '23090578_20120613.hdf5',
#  '23090593_20120625.hdf5',
#  '23090564_20130312.hdf5',
#  '23090631_20130128.hdf5',
#  '23090616_20140331.hdf5',
#  '23090606_20120619.hdf5',
#  '23090638_20131126.hdf5',
#  '23090629_20120830.hdf5',
#  '23090592_20130218.hdf5',
#  '23090625_20160111.hdf5',
#  '23090589_20140219.hdf5',
#  '23090617_20140211.hdf5',
#  '23090590_20121212.hdf5',
#  '23090619_20121210.hdf5',
#  '23090611_20150212.hdf5',
#  '23090612_20121213.hdf5',
#  '23090646_20120718.hdf5',
#  '23090600_20121108.hdf5',
#  '23090579_20141215.hdf5',
#  '23090630_20130213.hdf5',
#  '23090558_20120330.hdf5',
#  '23090591_20140124.hdf5',
#  '23090567_20160819.hdf5',
#  '23090635_20140710.hdf5',
#  '23090587_20150908.hdf5']

# %%
os.listdir('/mnt/submission/')
# Out:
# ['submit_files', 'submitted', 'log', 'result']

# %%
os.listdir('/mnt/backup/working/nnUNet/nnunet/nnUNet_trained_models/nnUNet/2d/Task555_PETCT/nnUNetTrainerV2__nnUNetPlansv2.1/all/')
# Out:
# ['model_final_checkpoint.model',
#  'progress.png',
#  'validation_raw',
#  'training_log_2021_10_20_02_28_21.txt',
#  'temp_allClasses',
#  'model_best.model.pkl',
#  'temp_perClass',
#  'validation_raw_postprocessed',
#  'training_log_2021_10_22_05_44_14.txt',
#  'model_final_checkpoint.model.pkl',
#  'model_best.model',
#  'postprocessing.json',
#  'debug.json']

# %%
os.listdir('/mnt/backup/working/nnUNet/nnunet/nnUNet_trained_models/nnUNet/2d/Task555_PETCT/nnUNetTrainerV2__nnUNetPlansv2.1/')
# Out:
# ['all', 'fold_1', 'plans.pkl', 'gt_niftis']
